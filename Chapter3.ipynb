# %% [markdown]
# # Python Data Types

# %%
=In programming, data type is an important concept.
Variables can store data of different types, and different types can do different things.
Python has the following data types built-in by default, in these categories:

# %%
Text Type:	str
Numeric Types:	int, float, complex
Sequence Types:	list, tuple, range
Mapping Type:	dict
Set Types:	set, frozenset
Boolean Type:	bool
Binary Types:	bytes, bytearray, memoryview
None Type:	NoneType

# %% [markdown]
# # Getting the Data Type

# %%
=You can get the data type of any object by using the type() function:

# %%
# Example variables of different types
integer_variable = 42
float_variable = 3.14
string_variable = "Hello, World!"
list_variable = [1, 2, 3, 4]
dict_variable = {'key': 'value'}

# Using type() to get the data types
print(type(integer_variable))  # Output: <class 'int'>
print(type(float_variable))    # Output: <class 'float'>
print(type(string_variable))   # Output: <class 'str'>
print(type(list_variable))     # Output: <class 'list'>
print(type(dict_variable))     # Output: <class 'dict'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# # Python Numbers

# %%
=There are three numeric types in Python:
int
float
complex

ExampleGet your own Python Server
x = 1    # int
y = 2.8  # float
z = 1j   # complex
# Out:
#   Cell In[2], line 1
#     =There are three numeric types in Python:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Type Conversion

# %%
=You can convert from one type to another with the int(), float(), and complex() methods

# %%
x=5
y=8.4
z=4j

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 5.0
# 8
# (5+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# # Random Number

# %%
=Python provides a module called random that you can use to generate random numbers.
The random module includes various functions to produce random values, and it offers more flexibility than a simple random() function.

# %%
import random

print(random.randrange(1, 10))
# Out:
# 3

# %%
import random 
print(random.randrange(1,30))
# Out:
# 19
